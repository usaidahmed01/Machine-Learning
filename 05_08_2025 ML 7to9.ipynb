# %%
#One Hot Encoding
#ChestPainType = [Typical:1, Atypical:2, Non-anginal:3, Asymptomatic:4]
#Gender=[Male:1,Female:0]
#ChestPainType=1,2,3,4

#ML model assumes 4>3>2>1 which is not True
'''
| Patient | ChestPain\_Typical | ChestPain\_Atypical | ChestPain\_Asymptomatic |
| ------- | ------------------ | ------------------- | ----------------------- |
| 1       | 1                  | 0                   | 0                       |
| 2       | 0                  | 1                   | 0                       |
| 3       | 0                  | 0                   | 1                       |
|4        | 0                  | 0                   | 0
'''
# Out:
# '\n| Patient | ChestPain\\_Typical | ChestPain\\_Atypical | ChestPain\\_Asymptomatic |\n| ------- | ------------------ | ------------------- | ----------------------- |\n| 1       | 1                  | 0                   | 0                       |\n| 2       | 0                  | 1                   | 0                       |\n| 3       | 0                  | 0                   | 1                       |\n|4        | 0                  | 0                   | 0\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Heart-UCI-Dataset/master/heart.csv')

# %%
df.columns = ['Age', 'Sex', 'ChestPainType' , 'RestBP','Cholesterol', 'FBS', 'RestECG',
              'MaxHR','ExerciseAngina','Oldpeak','ST_Slope','NumVesselsFluoro','Thal','Target']

# %%
df.head(2)
# Out:
#    Age  Sex  ChestPainType  RestBP  Cholesterol  FBS  RestECG  MaxHR  \
# 0   63    1              3     145          233    1        0    150
# 1   37    1              2     130          250    0        1    187
#
#    ExerciseAngina  Oldpeak  ST_Slope  NumVesselsFluoro  Thal  Target
# 0               0      2.3         0                 0     1       1
# 1               0      3.5         0                 0     2       1

# %%
df_encoded = pd.get_dummies(df, columns=['ChestPainType'], drop_first=True)

# %%
df_encoded.head()
# Out:
#    Age  Sex  RestBP  Cholesterol  FBS  RestECG  MaxHR  ExerciseAngina  \
# 0   63    1     145          233    1        0    150               0
# 1   37    1     130          250    0        1    187               0
# 2   41    0     130          204    0        0    172               0
# 3   56    1     120          236    0        1    178               0
# 4   57    0     120          354    0        1    163               1
#
#    Oldpeak  ST_Slope  NumVesselsFluoro  Thal  Target  ChestPainType_1  \
# 0      2.3         0                 0     1       1            False
# 1      3.5         0                 0     2       1            False
# 2      1.4         2                 0     2       1             True
# 3      0.8         2                 0     2       1             True
# 4      0.6         2                 0     2       1            False
#
#    ChestPainType_2  ChestPainType_3
# 0            False             True
# 1             True            False
# ...

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestBP  Cholesterol  FBS  RestECG  MaxHR  \
# 0   63    1              3     145          233    1        0    150
# 1   37    1              2     130          250    0        1    187
# 2   41    0              1     130          204    0        0    172
# 3   56    1              1     120          236    0        1    178
# 4   57    0              0     120          354    0        1    163
#
#    ExerciseAngina  Oldpeak  ST_Slope  NumVesselsFluoro  Thal  Target
# 0               0      2.3         0                 0     1       1
# 1               0      3.5         0                 0     2       1
# 2               0      1.4         2                 0     2       1
# 3               0      0.8         2                 0     2       1
# 4               1      0.6         2                 0     2       1

# %%
adf = pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Heart-UCI-Dataset/master/heart.csv')

# %%
adf
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.dtypes
# Out:
# Age                   int64
# Sex                   int64
# ChestPainType         int64
# RestBP                int64
# Cholesterol           int64
# FBS                   int64
# RestECG               int64
# MaxHR                 int64
# ExerciseAngina        int64
# Oldpeak             float64
# ST_Slope              int64
# NumVesselsFluoro      int64
# Thal                  int64
# Target                int64
# dtype: object

# %%
df_encoded2 = pd.get_dummies(df, columns=['ChestPainType', 'Thal'], drop_first=True)

# %%
df_encoded2.head()
# Out:
#    Age  Sex  RestBP  Cholesterol  FBS  RestECG  MaxHR  ExerciseAngina  \
# 0   63    1     145          233    1        0    150               0
# 1   37    1     130          250    0        1    187               0
# 2   41    0     130          204    0        0    172               0
# 3   56    1     120          236    0        1    178               0
# 4   57    0     120          354    0        1    163               1
#
#    Oldpeak  ST_Slope  NumVesselsFluoro  Target  ChestPainType_1  \
# 0      2.3         0                 0       1            False
# 1      3.5         0                 0       1            False
# 2      1.4         2                 0       1             True
# 3      0.8         2                 0       1             True
# 4      0.6         2                 0       1            False
#
#    ChestPainType_2  ChestPainType_3  Thal_1  Thal_2  Thal_3
# 0            False             True    True   False   False
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number])

# %%
plt.figure(figsize=(14,14))
sns.heatmap(numeric_df.corr(), annot=True, cmap='Blues')
plt.show()

# %%
correlation_matrix = df_encoded2.corr()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#Colinearity: occurs when two or more features (independent variables) in a dataset are highly correlated with each other
